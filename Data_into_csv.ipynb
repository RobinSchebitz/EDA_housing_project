# %% [markdown]
# # Import of Data
#
# We want to import the data from the database in the csv file house_sales.csv

# %% [markdown]
# ## Using psycopg2 and the credentials in our .env file to access PostgreSQL database

# %%
import pandas as pd
import psycopg2
import os
from dotenv import load_dotenv

load_dotenv()

DATABASE = os.getenv('DATABASE')
USER_DB = os.getenv('USER_DB')
PASSWORD = os.getenv('PASSWORD')
HOST = os.getenv('HOST')
PORT = os.getenv('PORT')

# %%
# Establish a connection with psycopg2

conn = psycopg2.connect(
    database=DATABASE,
    user=USER_DB,
    password=PASSWORD,
    host=HOST,
    port=PORT
)

# %%
# Retrieving the data and importing to a Pandas Dataframe, then closing the connection

query_string = 'SELECT * FROM eda.king_county_house_sales hs LEFT JOIN eda.king_county_house_details hd on hd.id = hs.house_id'
df_psycopg = pd.read_sql(query_string, conn)
conn.close()
# Out:
# /var/folders/g_/1j1nrg9s2j79cfcwpn2lrngr0000gn/T/ipykernel_72108/110659921.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_psycopg = pd.read_sql(query_string, conn)

# %%
# Check dataframe

df_psycopg.head()
# Out:
#          date     price    house_id  id          id  bedrooms  bathrooms  \
# 0  2014-10-13  221900.0  7129300520   1  7129300520       3.0       1.00
# 1  2014-12-09  538000.0  6414100192   2  6414100192       3.0       2.25
# 2  2015-02-25  180000.0  5631500400   3  5631500400       2.0       1.00
# 3  2014-12-09  604000.0  2487200875   4  2487200875       4.0       3.00
# 4  2015-02-18  510000.0  1954400510   5  1954400510       3.0       2.00
#
#    sqft_living  sqft_lot  floors  ...  grade  sqft_above  sqft_basement  \
# 0       1180.0    5650.0     1.0  ...      7      1180.0            0.0
# 1       2570.0    7242.0     2.0  ...      7      2170.0          400.0
# 2        770.0   10000.0     1.0  ...      6       770.0            0.0
# 3       1960.0    5000.0     1.0  ...      7      1050.0          910.0
# 4       1680.0    8080.0     1.0  ...      8      1680.0            0.0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
#export the data to a csv-file - be careful it is within the /data folder as it will be ignored by git
df_psycopg.to_csv('data/house_sales.csv',index=False)
